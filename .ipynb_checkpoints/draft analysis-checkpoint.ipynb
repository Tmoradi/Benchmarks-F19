# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelEncoder

# %%
# get all of the subtypes and the days of extension 
data = pd.read_csv('cases.csv')
# Out:
# C:\Users\tiamm\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (5,15,23,43,44,51,53,55,63,67,71,73,74,79,92,107,108,126,127,130,132,144) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# the percent of Civil cases that are reversed 
data
# Out:
#           Case Id                                          Case Name  \
# 0     2008-P-0001                   PETER G. HILL vs. JAMES LUKOWIAK
# 1     2008-P-1002    CASELLA WASTE MANAGEMENT OF MA vs. JOHN TAMBURO
# 2     2008-P-1006  FARMER & FLIER ASSOCIATES vs. GUILFORD TRANSPO...
# 3     2008-P-1007                                      B.M. vs. J.C.
# 4     2008-P-1014                 SOLANGE DASILVA vs. MICHAEL BERMAN
# ...           ...                                                ...
# 6807    SJC-12384                                     IMPOUNDED CASE
# 6808    SJC-12387                    RONALDO CEPEDA vs. COMMONWEALTH
# 6809    SJC-12403                                     IMPOUNDED CASE
# 6810    SJC-12407  NATALY MINKINA vs. ROGERS, POWERS & SCHWARTZ, LLP
# 6811    SJC-12418                            G.G. vs. L.R. & another
#
#      Case Type               Case Status  Entry Date Argued Date Status Date  \
# ...

# %%
# Defendant Extension Days for reversed cases 
reversed_ = data[data['Has Reverse'] == 'Yes']
reversed_['Defendant Extension Days'].describe()
# Out:
# count    115.000000
# mean      87.260870
# std      101.126296
# min        3.000000
# 25%       41.000000
# 50%       60.000000
# 75%       93.500000
# max      741.000000
# Name: Defendant Extension Days, dtype: float64

# %%
# Defendant Extension Dats for Affirmed cases 
affirmed = data[data['Has Affirm'] == 'Yes']
affirmed['Defendant Extension Days'].describe()
# Out:
# count     922.000000
# mean       82.753796
# std       126.593921
# min         2.000000
# 25%        42.000000
# 50%        61.000000
# 75%        94.000000
# max      3304.000000
# Name: Defendant Extension Days, dtype: float64

# %%
affirmed.dropna(how='all',axis=1,inplace=True)
# Out:
# C:\Users\tiamm\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 6805    Yes
# 6806    Yes
# 6808    Yes
# 6810    Yes
# 6811    Yes
# Name: Has Affirm, Length: 5061, dtype: object

# %%
reversed_
# Out:
#           Case Id                                          Case Name  \
# 14    2008-P-0104  CITY OF NEWBURYPORT vs. ELEANOR J. WOODMAN & a...
# 17    2008-P-1051                 DOUGLAS D. DENT vs. ELAINE M. DENT
# 19    2008-P-1053  VERMONT MUTUAL INSURANCE COMPANY & another vs....
# 35    2008-P-1088  STANLEY GENEGA & another vs. LEO CORCORAN & ot...
# 44    2008-P-0111                 RICHARD GOODHUE vs. BARBARA MERSAL
# ...           ...                                                ...
# 6789    SJC-12287  KIRIBATI SEAFOOD COMPANY, LLC & another vs. DE...
# 6791    SJC-12291            ANDREW SEGAL vs. GENITRIX, LLC & OTHERS
# 6792    SJC-12293                     COMMONWEALTH vs. EDWARD CURRAN
# 6801    SJC-12315  IBNER CASSEUS & another vs. EASTERN BUS COMPAN...
# 6810    SJC-12407  NATALY MINKINA vs. ROGERS, POWERS & SCHWARTZ, LLP
#
#      Case Type               Case Status  Entry Date Argued Date Status Date  \
# ...

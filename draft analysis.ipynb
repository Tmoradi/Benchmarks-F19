# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelEncoder

# %%
# get all of the subtypes and the days of extension 
data = pd.read_csv('cases.csv')
# Out:
# C:\Users\tiamm\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (5,10,23,42,52,53,54,91,98,107,108,110,115,118,139,142,144) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.columns.tolist()
# Out:
# ['Case Id',
#  'Case Name',
#  'Case Type',
#  'Case Status',
#  'Entry Date',
#  'Argued Date',
#  'Status Date',
#  'Decision Date',
#  'Has Affirm',
#  'Has Reverse',
#  'Out-of-state counsel',
#  'amid',
#  'Third-party plaintiff Extensions',
#  'SJ Number',
#  'cmt',
#  'Third-party Defendant',
#  'Out-of-state attorney',
#  'clk',
#  'Party Name Impounded Extensions',
#  'Other Extensions',
#  'Pro Se Other',
#  'Lower Court',
#  'e3pp',
#  '(Lower Court: Jury)',
#  'Defendant Extensions',
#  'Brief Due',
#  'Pro Se Other Appellee',
#  'Invited to file amicus brief',
#  'Panel',
#  'TC Number',
#  'Transferred to Court',
#  'Pro Se Other Appellant Extension Days',
#  'Lower Ct Judge',
#  'Other',
#  'Guardian ad litem',
#  'Pro Se Amicus (plaintiff)',
#  'Out of state counsel (plaintiff)',
#  'Pro Se Defendant Extensions',
#  'Pro Se Plaintiff Extension Days',
#  'Massachusetts Correctional Institution',
#  'Clerk for Commonwealth',
#  'Pro Se Third-party Defendant',
# ...

# %%
# Getting the subnature of individual cases / the days of extension of the Plantiff Extensions
Sub_Nature = data['Sub-Nature']
days_of_extensions = data['Plaintiff Extension Days']

# %%
# get whether the cases where reversed or not  / the type of case 
type_case = data['Case Type']

# %%
type_case.values.tolist()
# Out:
# {'Criminal'}

# %%
# Out:
# [2.0,
#  2.0,
#  4.0,
#  nan,
#  nan,
#  2.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  2.0,
#  nan,
#  2.0,
#  nan,
#  nan,
#  nan,
#  2.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  2.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  2.0,
#  3.0,
#  2.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  5.0,
#  2.0,
#  nan,
#  nan,
#  nan,
#  2.0,
#  nan,
#  2.0,
#  nan,
#  nan,
#  nan,
#  2.0,
#  nan,
#  2.0,
#  nan,
#  2.0,
#  nan,
#  2.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  3.0,
#  2.0,
#  2.0,
#  nan,
#  4.0,
#  nan,
#  nan,
#  nan,
#  2.0,
#  nan,
#  nan,
#  nan,
#  2.0,
#  nan,
#  2.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  2.0,
#  2.0,
#  2.0,
#  nan,
#  2.0,
#  3.0,
#  nan,
#  nan,
#  2.0,
#  4.0,
#  3.0,
#  3.0,
#  2.0,
#  nan,
#  2.0,
#  nan,
#  2.0,
#  nan,
#  2.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  3.0,
#  nan,
#  nan,
#  2.0,
#  nan,
#  nan,
#  nan,
#  2.0,
#  2.0,
#  nan,
#  nan,
#  nan,
#  2.0,
# ...

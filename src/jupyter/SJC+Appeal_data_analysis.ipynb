# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from matplotlib import font_manager as fm
import matplotlib as mpl

# %% [markdown]
# # SJC

# %%
# old cases from previous group
old_cases = pd.read_csv('cases.csv')
old_cases.head()
# Out:
#        Case Id                            Case Name Case Type  \
# 0  2008-P-0100     COMMONWEALTH vs. ANGEL RODRIGUEZ  Criminal
# 1  2008-P-1000    Commonwealth vs. Edward A. Amaral  Criminal
# 2  2008-P-1001  Commonwealth vs. James A. Moorcraft  Criminal
# 3  2008-P-1005     COMMONWEALTH vs. ARIEL MALDONADO  Criminal
# 4  2008-P-1009     COMMONWEALTH vs. DAVID E. GARCIA  Criminal
#
#                Case Status  Entry Date Argued Date Status Date Decision Date  \
# 0  Closed: Rescript issued  01/17/2008         NaN  06/08/2009    04/03/2009
# 1  Closed: Rescript issued  06/13/2008         NaN  10/06/2010    07/23/2010
# 2  Closed: Rescript issued  06/13/2008         NaN  09/01/2010    05/14/2010
# 3  Closed: Rescript issued  06/13/2008         NaN  05/20/2009    04/22/2009
# 4  Closed: Rescript issued  06/16/2008         NaN  09/29/2009    09/01/2009
#
#   Has Affirm Has Reverse                ...                 Pro Se Amicus  \
# 0        Yes         NaN                ...                           NaN
# 1        Yes         NaN                ...                           NaN
# 2        Yes         NaN                ...                           NaN
# 3        Yes         NaN                ...                           NaN
# 4        NaN         NaN                ...                           NaN
#
#    Pro Se pet  Amicus (defendant) Pro Se Petitioner  \
# 0         NaN                 NaN               NaN
# 1         NaN                 NaN               NaN
# 2         NaN                 NaN               NaN
# 3         NaN                 NaN               NaN
# 4         NaN                 NaN               NaN
#
#    Out-of-state counsel for defendant  Route to SJC  comp  \
# 0                                 NaN           NaN   NaN
# 1                                 NaN           NaN   NaN
# 2                                 NaN           NaN   NaN
# 3                                 NaN           NaN   NaN
# 4                                 NaN           NaN   NaN
#
#    Student attorney purs to SJC 3:03  Pro Se poth  \
# 0                                NaN          NaN
# 1                                NaN          NaN
# 2                                NaN          NaN
# 3                                NaN          NaN
# 4                                NaN          NaN
#
#    Out-of-state counsel for appellee
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
# [5 rows x 149 columns]

# %%
# Data cleaning, show cases are appealed or not

old_cases_app = old_cases[old_cases['Court Type'] == 'APPEALS COURT']
old_cases_sjc = old_cases[old_cases['Court Type'] == 'SUPREME JUDICIAL COURT']
old_cases_sjc = old_cases_sjc[['Case Name', 'Case Type', 'Has Affirm', 'Has Reverse', 'Court Type','Lower Ct Judge']]
old_cases_sjc = old_cases_sjc.rename(columns={'Lower Ct Judge': 'judge'})
old_cases_sjc.head()

old_cases_sjc["Has Affirm"]= old_cases_sjc["Has Affirm"].astype(str)
old_cases_sjc["Has Reverse"]= old_cases_sjc["Has Reverse"].astype(str)

def define_reverse(df):
    appealed = []
    for i, row in df.iterrows():
        if (row['Has Affirm']  ==   'Yes' ) & (row['Has Reverse'] ==   'nan' ):
            appealed.append('No')
        elif (row['Has Affirm']  ==   'nan' ) & (row['Has Reverse']  ==   'Yes' ):
            appealed.append('Yes')
        else:
            appealed.append('Partially')
    return appealed

old_cases_sjc['appealed'] = define_reverse(old_cases_sjc)
old_cases_sjc = old_cases_sjc.drop(['Has Reverse', 'Has Affirm', 'Court Type'], axis = 1)
old_cases_sjc.head()
# Out:
#                                               Case Name Case Type  \
# 6225  COMMONWEALTH vs. LUIS VASQUEZ (and five compan...  Criminal
# 6226                          COMMONWEALTH vs. TU TRINH  Criminal
# 6227             COMMONWEALTH vs. DERYCK LONG & another  Criminal
# 6228                      COMMONWEALTH vs. RODOLFO CARR  Criminal
# 6229                     Commonwealth v. Joseph Facella  Criminal
#
#                         judge appealed
# 6225     Patrick F. Brady, J.       No
# 6226       Linda E. Giles, J.       No
# 6227     Janet L. Sanders, J.       No
# 6228  Christine M. McEvoy, J.       No
# 6229        David A. Lowy, J.       No

# %%
new_cases_sjc = pd.read_csv('new_sjc_data.csv')

# %%
# Preprocessing for concating old cases dataframe and new cases dataframe
new_cases_sjc = new_cases_sjc.loc[:, ~new_cases_sjc.columns.str.contains('^Unnamed')]
new_cases_sjc = new_cases_sjc.rename(columns={'cases': 'Case Name', 'type' : 'Case Type' })
new_cases_sjc = new_cases_sjc.drop(['headnote','text','caseid'], axis = 1)

# %%
new_cases_sjc['Case Type'] = new_cases_sjc['Case Type'].str.capitalize()
new_cases_sjc.head()
# Out:
#                                            Case Name Case Type   appealed  \
# 0                              in the matter of e.c.  Criminal        Yes
# 1                  commonwealth  vs.  joseph wright.  Criminal         No
# 2  brian rafferty  vs.  merck & co., inc., & anot...     Civil         No
# 3              commonwealth  vs.  johnelle m. brown.  Criminal         No
# 4                            commonwealth  vs.  g.f.     Civil  Partially
#
#                      judge
# 0            Not Mentioned
# 1  Howard J. Whitehead, J.
# 2   Kenneth J. Fishman, J.
# 3     Michele B. Hogan, J.
# 4            Not Mentioned

# %%
# combine 2 dataframes together for analyzing
all_cases_sjc = pd.concat([old_cases_sjc,new_cases_sjc],axis= 0)
all_cases_sjc
# Out:
# /Users/ecyecy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                                               Case Name Case Type   appealed  \
# 6225  COMMONWEALTH vs. LUIS VASQUEZ (and five compan...  Criminal         No
# 6226                          COMMONWEALTH vs. TU TRINH  Criminal         No
# 6227             COMMONWEALTH vs. DERYCK LONG & another  Criminal         No
# 6228                      COMMONWEALTH vs. RODOLFO CARR  Criminal         No
# 6229                     Commonwealth v. Joseph Facella  Criminal         No
# 6230                      COMMONWEALTH vs. JIMMY ALCIDE  Criminal  Partially
# 6231                    COMMONWEALTH vs. ERIC J. DURAND  Criminal        Yes
# 6232                                     IMPOUNDED CASE  Criminal  Partially
# 6233                   COMMONWEALTH vs. FRANCIS X. LANG  Criminal         No
# 6234  COMMONWEALTH vs. SINY VAN TRAN (and thirteen c...  Criminal         No
# 6235                     COMMONWEALTH vs. JOSEPH LENNON  Criminal         No
# 6236                      COMMONWEALTH vs. ANDRE WALKER  Criminal         No
# 6237                   COMMONWEALTH vs. PIERRE P. CADET  Criminal         No
# 6238                        COMMONWEALTH vs. CHARON RAY  Criminal         No
# 6239                          LEE FORT vs. COMMONWEALTH  Criminal         No
# 6240                   COMMONWEALTH vs. SOLANGE ANESTAL  Criminal        Yes
# 6241                  COMMONWEALTH vs. NORTON CARTRIGHT  Criminal         No
# 6242                   COMMONWEALTH vs. KYRON A. GORHAM  Criminal         No
# 6243                    Commonwealth v. Odair Fernandes  Criminal         No
# 6244                  COMMONWEALTH vs. SEAN FITZPATRICK  Criminal         No
# 6245                   COMMONWEALTH vs. DAVID T. MILLER  Criminal         No
# 6246                 COMMONWEALTH vs. FRANK DiBENEDETTO  Criminal         No
# 6247                  COMMONWEALTH vs. JAMES E. BRESCIA  Criminal         No
# 6248                     COMMONWEALTH vs. DEREK WOOLLAM  Criminal         No
# 6249               COMMONWEALTH vs. KENNETH G. HAMILTON  Criminal  Partially
# 6250                         COMMONWEALTH vs. RYAN BOIS  Criminal         No
# 6251                       COMMONWEALTH vs. REMEL AHART  Criminal         No
# 6252                COMMONWEALTH vs. CHITEARA M. THOMAS  Criminal         No
# 6253                  COMMONWEALTH vs. CLEVELAND MARTIN  Criminal         No
# 6254                   COMMONWEALTH vs. ELYSEE BRESILLA  Criminal         No
# ...                                                 ...       ...        ...
# 299                  commonwealth  vs.  bruce anderson.  Criminal         No
# 300   raymond p. vinnie  vs.  superintendent, massac...  Criminal         No
# 301                      norman perez vs. commonwealth.     Civil         No
# 302                   commonwealth  vs.  jermaine watt.  Criminal        Yes
# 303          commonwealth  vs.  stephanie a. fernandes.  Criminal        Yes
# 304                     commonwealth  vs.  john odgren.  Criminal         No
# 305                    commonwealth  vs.  joshua reyes.  Criminal         No
# 306   boston globe media partners, llc  vs.  chief j...  Criminal  Partially
# 307   veolia energy boston, inc.  vs.  board of asse...     Civil         No
# 308                      commonwealth  vs.  jean gomes.  Criminal        Yes
# 309   john doe, sex offender registry board no. 2365...     Civil         No
# 310   joseph p. marchese  vs.  boston redevelopment ...     Civil         No
# 311   allen h. davis  vs.  william comerford & another.     Civil        Yes
# 312            commonwealth  vs.  deneisha d. newberry.  Criminal         No
# 313   lynne blanchard & othersvs.  steward carney ho...     Civil         No
# 314   the mclean hospital corporation  vs.  town of ...     Civil        Yes
# 315                   commonwealth  vs.  damion linton.  Criminal         No
# 316   commerce insurance company vs. justina m. szaf...     Civil  Partially
# 317                  commonwealth  vs.  jesse carrillo.  Criminal  Partially
# 318                 commonwealth  vs.  william moseley.  Criminal         No
# 319   board of higher education  vs.  commonwealth e...     Civil         No
# 320             commonwealth  vs.  zachariah j. larose.  Criminal         No
# 321                  commonwealth  vs.  abdullah yasin.  Criminal         No
# 322                      commonwealth  vs.  raul matta.  Criminal  Partially
# 323                    commonwealth  vs.  dennis colon.  Criminal         No
# 324   ubs financial services, inc.  vs.  donna m. al...     Civil  Partially
# 325                commonwealth  vs.  carlos l. vieira.  Criminal         No
# 326                  sayyid coggins  vs.  commonwealth.  Criminal        Yes
# 327                   commonwealth  vs.  ervin johnson.  Criminal         No
# 328              commonwealth  vs.  frederick h. perry.  Criminal  Partially
#
#                             judge
# 6225         Patrick F. Brady, J.
# 6226           Linda E. Giles, J.
# 6227         Janet L. Sanders, J.
# 6228      Christine M. McEvoy, J.
# 6229            David A. Lowy, J.
# 6230         S. Jane Haggerty, J.
# 6231       D. Lloyd Macdonald, J.
# 6232       Thomas E. Connolly, J.
# 6233          Stephen E. Neel, J.
# 6234          Stephen E. Neel, J.
# 6235         Peter M. Lauriat, J.
# 6236      Raymond J. Brassard, J.
# 6237         Frank M. Gaziano, J.
# 6238         Janet L. Sanders, J.
# 6239      Roderick L. Ireland, J.
# 6240          Richard J. Chin, J.
# 6241      Christine M. McEvoy, J.
# 6242        Gary A. Nickerson, J.
# 6243       Margaret R. Hinkle, J.
# 6244         Kathe M. Tuttman, J.
# 6245  Barbara A. Dortch-Okara, J.
# 6246       Robert A. Mulligan, J.
# 6247    Wendie I. Gershengorn, J.
# 6248  Barbara A. Dortch-Okara, J.
# 6249    James L. LaMothe, Jr., J.
# 6250         Janet L. Sanders, J.
# 6251                          NaN
# 6252        Thomas A. Connors, J.
# 6253        Regina L. Quinlan, J.
# 6254         Sandra L. Hamlin, J.
# ...                           ...
# 299           Daniel M. Wrenn, J.
# 300          Frank M. Gaziano, J.
# 301                 Not Mentioned
# 302          Richard J. Carey, J.
# 303       Janet Kenton-Walker, J.
# 304          S. Jane Haggerty, J.
# 305         C. Jeffrey Kinder, J.
# 306             David A. Lowy, J.
# 307                 Not Mentioned
# 308     Raymond P. Veary, Jr., J.
# 309            Paul D. Wilson, J.
# 310         Rosemary Connolly, J.
# 311            Diana H. Horan, J.
# 312             David A. Lowy, J.
# 313   Joseph F. Leighton, Jr., J.
# 314          Karyn F. Scheier, J.
# 315          Peter M. Lauriat, J.
# 316         Richard T. Tucker, J.
# 317          John A. Agostini, J.
# 318          Kathe M. Tuttman, J.
# 319                 Not Mentioned
# 320           Thomas H. Estes, J.
# 321                 Not Mentioned
# 322            Daniel A. Ford, J.
# 323     Richard E. Welch, III, J.
# 324            Karen F. Green, J.
# 325            Lynn C. Rooney, J.
# 326                 Not Mentioned
# 327           Barbara A. Lenk, J.
# 328                 Not Mentioned
#
# [754 rows x 4 columns]

# %%
# Count cases that are affirmed, reversed, and partially reversed

total_count = all_cases_sjc.appealed.count()

reverse_count = all_cases_sjc.loc[(all_cases_sjc['appealed'] == 'Yes')].appealed.count()
affirm_count = all_cases_sjc.loc[(all_cases_sjc['appealed'] == 'No')].appealed.count()
partially_reverse_count = all_cases_sjc.loc[(all_cases_sjc['appealed'] == 'Partially')].appealed.count()
print('reverse_count = ', reverse_count, '    affirm_count = ' , affirm_count, '    partially_reverse_count = ' , partially_reverse_count )
# Out:
# reverse_count =  136     affirm_count =  468     partially_reverse_count =  150

# %%
# Visulize as pie chart

all_cases_sjc_pie_chart = all_cases_sjc.groupby('appealed').size()
all_cases_sjc_pie_chart.plot(kind='pie', autopct='%.2f%%', fontsize=20, figsize=(8, 8), subplots = True, legend = False)
plt.title("Ratio of cases reversed in MA")
plt.ylabel("")
plt.show()

# %%
# Read from appeal court (new cases)
# # Count cases that are from appeal court, SJC, and the total number

new_case_app = pd.read_csv('new_case_data.csv')

appeal_cases_count =  new_case_app.cases.count() + old_cases_app.URL.count()
sjc_cases_count =  all_cases_sjc.appealed.count()
all_cases_count = sjc_cases_count + appeal_cases_count

print ('appeal_cases_count = ', appeal_cases_count,  '    sjc_cases_count = ',sjc_cases_count,  '   all_cases_count = ',   all_cases_count)
# Out:
# appeal_cases_count =  6517     sjc_cases_count =  754    all_cases_count =  7271

# %%
# Visualize as bar plot

objects = ('appeal_cases_count', 'sjc_cases_count', 'all_cases_count')
y_pos = np.arange(len(objects))
performance = [appeal_cases_count ,sjc_cases_count ,all_cases_count]
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Case number')
plt.title('Count and ratio of cases from appeal court or SJC')
# Out:
# Text(0.5, 1.0, 'Count and ratio of cases from appeal court or SJC')

# %%
# prepare for distribution among civil vs criminal cases from SJC in MA
all_cases_sjc_CaseType = all_cases_sjc[['Case Type']][all_cases_sjc['appealed'] == "No"]

# %%
# Visualize as pie chart

all_cases_sjc_CaseType_pie_chart = all_cases_sjc_CaseType.groupby('Case Type').size()
all_cases_sjc_CaseType_pie_chart.plot(kind='pie', autopct='%.2f%%', fontsize=20, figsize=(8, 8), subplots = True, legend = False)
plt.title("Type of cases reversed from SJC in MA")
plt.ylabel("")
plt.show()

# %% [markdown]
# # Appeal

# %%
new_data = pd.read_csv("new_case_data.csv")

# %%
new_data.head()
# Out:
#    Unnamed: 0                                              cases  \
# 0        1622  ann skiffington  vs.  liberty mutual insurance...
# 1        1623              commonwealth  vs.  radhames gonzalez.
# 2        1624              commonwealth  vs.  stanley fredericq.
# 3        1625  cedar-fieldstone marketplace, lp  vs.  t.s. fi...
# 4        1626  citadel realty, llc  vs.  endeavor capital nor...
#
#                                             headnote  \
# 0  motor vehicle, insurance. insurance, motor veh...
# 1  corrected june 1, 2018controlled substances.  ...
# 2  further appellate review granted,  480 mass. 1...
# 3  guaranty.  contract, lease of real estate, rel...
# 4  practice, civil, interlocutory appeal, motion ...
#
#                                                 text      type  \
# 0  following a motor vehicle accident, the plaint...     civil
# 1  after a jury trial in superior court, the defe...  criminal
# 2  as a result of information gathered in connect...  criminal
# 3  in this case, we consider whether the release ...     civil
# 4  this appeal presents occasion to clarify the s...     civil
#
#       lower court judge case status
# 0  Constance M. Sweeney      Affirm
# 1    Thomas P. Billings      Affirm
# 2                   0.0         0.0
# 3       Renee P. Dupuis      Affirm
# 4   William F. Sullivan     reverse

# %%
for i in range(len(new_data)):
    temp = new_data["case status"].iloc[i]
    if temp == "partially reverse" :
        new_data["case status"].iloc[i] = "partially reversed"
    elif temp == "reverse":
        new_data["case status"].iloc[i] = "reversed"
    elif temp == '0.0':
        new_data["case status"].iloc[i] = "uncertain"
    else:
        new_data["case status"].iloc[i] = new_data["case status"].iloc[i].lower()

# %% [markdown]
# ### 2018/3 ~ 2019/11

# %%
new_civil_case = new_data[new_data["type"] == 'civil']
new_cr_case = new_data[new_data["type"] == 'criminal']

# %%
new_civil_case_num = len(new_civil_case)
new_cr_case_num = len(new_cr_case)
new_total_case = len(new_data)

# %%
new_data_chart = new_data.groupby('type').size()
new_data_chart.plot(kind='pie', autopct='%.2f%%', fontsize=20, figsize=(8, 8), subplots = True, legend = False)
plt.title("Type of cases reversed of Appeal court in MA 2018/6 to 2019/11")
plt.ylabel("")
plt.show()

# %%
for i in range(len(new_data)):
    temp = new_data["case status"].iloc[i]
    new_data["case status"].iloc[i] = temp.lower()

# %%
new_data_chart2 = new_data.groupby("case status").size()
new_data_chart2.plot(kind='pie', autopct='%.2f%%', fontsize=20, figsize=(8, 8), subplots = True, legend = False)
plt.title("Cases status of Appeal court in MA 2018/6 to 2019/11")
plt.ylabel("")
plt.show()

# %%
new_civil_chart2 = new_civil_case.groupby("case status").size()
new_civil_chart2.plot(kind='pie', autopct='%.2f%%', fontsize=20, figsize=(8, 8), subplots = True, legend = False)
plt.title("Cases status of Appeal court in MA 2018/6 to 2019/11")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### all civil cases that public in MA

# %%
data = pd.read_csv("cases.csv")

# %%
old_appeal_case = data[data['Court Type'] == "APPEALS COURT"][['Case Name', 'Case Type', 'Has Affirm', 'Has Reverse', 'Court Type']]

# %%
old_appeal_case["Has Affirm"]= old_appeal_case["Has Affirm"].astype(str)
old_appeal_case["Has Reverse"]= old_appeal_case["Has Reverse"].astype(str)

def define_reverse(df):
    appealed = []
    for i, row in df.iterrows():
        if (row['Has Reverse']  ==   'Yes' ) :
            appealed.append('reversed')
        elif (row['Has Affirm']  ==   'Yes')  :
            appealed.append('affirm')
        else:
            appealed.append('partially reversed')
    return appealed

old_appeal_case['reverse'] = define_reverse(old_appeal_case)
old_appeal_case = old_appeal_case.drop(['Has Reverse', 'Has Affirm', 'Court Type'], axis = 1)

# %%
new_appeal_case = new_civil_case[["cases","type","case status"]]

# %%
new_appeal_case = new_appeal_case.rename(columns={"cases": "Case Name", "type": "Case Type","case status" : "reverse"})

# %%
all_civil_case = pd.concat([old_appeal_case,new_appeal_case],axis= 0)

# %%
civil_chart = all_civil_case.groupby("reverse").size()
civil_chart.plot(kind='pie', autopct='%.2f%%', fontsize=20, figsize=(8, 8), subplots = True, legend = False)
plt.title("Civil Cases status of Appeal court in MA 2018/6 to 2019/11")
plt.ylabel("")
plt.show()

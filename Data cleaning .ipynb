# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
# get all of the subtypes and the days of extension 
data1 = pd.read_csv('cases.csv')

# %%
data1['Case Name'][0]
# Out:
# 'peter g. hill vs. james lukowiak'

# %%
df_appeals = pd.read_csv('opinions_data_csv/appeal_draft.csv')
df_sjc = pd.read_csv('opinions_data_csv/sjc_draft.csv')

# %%
# to visualize the data.
# data1.columns.tolist()

# %%
# df_appeals

# %%
df_appeals_civil = df_appeals[df_appeals['type'] == 'civil']
df_sjc_civil = df_sjc[df_sjc['type'] == 'civil']

# %%
civil_opinions = pd.concat([df_appeals_civil,df_sjc_civil],axis=0)
# Out:
# C:\Users\tiamm\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
civil_opinions
# Out:
#         caseid                                              cases  \
# 2          NaN              linda s. bowers  vs.  p. wile's, inc.
# 5          NaN  marcia d. bellermann & othersvs.  fitchburg ga...
# 13         NaN  suffolk construction company, inc.  vs.  bench...
# 17         NaN  engie gas & lng llcvs.  department of public u...
# 19         NaN  robert maclaurin& anothervs.  city of holyoke ...
# ..         ...                                                ...
# 628  sjc-12712  allen h. davis  vs.  william comerford & another.
# 630  sjc-12618  lynne blanchard & othersvs.  steward carney ho...
# 631  sjc-12675  the mclean hospital corporation  vs.  town of ...
# 633  sjc-12655  commerce insurance company vs. justina m. szaf...
# 641  sjc-12662  ubs financial services, inc.  vs.  donna m. al...
#
#                                               headnote  \
# 2    negligence, retailer. notice. practice, civil,...
# 5    electric company. public utilities, electric c...
# ...

# %%
civil_opinions['cases']
# Out:
# 2    linda s. bowers  vs.  p. wile's, inc.
# 2    linda s. bowers  vs.  p. wile's, inc.
# Name: cases, dtype: object

# %%
# Now lets compare the cases we have to the cases that the previous group collected

# %%
# Defendant Extension Days for reversed cases 
reversed_ = data[data['Has Reverse'] == 'Yes']
reversed_['Defendant Extension Days'].describe()

# %%
# Defendant Extension Dats for Affirmed cases 
affirmed = data[data['Has Affirm'] == 'Yes']
affirmed['Defendant Extension Days'].describe()

# %%
affirmed.dropna(how='all',axis=1,inplace=True)

# %%
reversed_
